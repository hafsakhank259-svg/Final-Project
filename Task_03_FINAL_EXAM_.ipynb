# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsakhank259-svg/Final-Project/blob/main/Task_03_FINAL_EXAM_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Calculator Program

# %%
# Ask user how many calculations they want
count = int(input("How many calculations do you want to perform? "))

for i in range(count):
    print("\nCalculation", i + 1)

    # Take two numbers
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    # Take operator
    operator = input("Enter operator (+, -, *, /): ")

    # Perform calculation
    if operator == "+":
        print("Result:", num1 + num2)

    elif operator == "-":
        print("Result:", num1 - num2)

    elif operator == "*":
        print("Result:", num1 * num2)

    elif operator == "/":
        if num2 == 0:
            print("Error: Division by zero is not allowed")
        else:
            print("Result:", num1 / num2)

    else:
        print("Error: Invalid operator")
# Out:
# How many calculations do you want to perform? 5
#
# Calculation 1
# Enter first number: 3
# Enter second number: 2
# Enter operator (+, -, *, /): +
# Result: 5.0
#
# Calculation 2
# Enter first number: 7
# Enter second number: 2
# Enter operator (+, -, *, /): *
# Result: 14.0
#
# Calculation 3
# Enter first number: 10
# Enter second number: 8
# Enter operator (+, -, *, /): -
# Result: 2.0
#
# Calculation 4
# Enter first number: 6
# Enter second number: 18
# Enter operator (+, -, *, /): /
# Result: 0.3333333333333333
#
# Calculation 5
# Enter first number: 57
# Enter second number: 47
# Enter operator (+, -, *, /): +
# Result: 104.0
